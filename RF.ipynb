# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
from sklearn import set_config
set_config(print_changed_only=False)
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cleaned_merged_file.csv')
df = df.dropna()
df
# Out:
#                              Movie Name       CSS Language  Runtime (min.)  \
# 0                          interstellar  0.300000  English             169
# 1                         thedarkknight  0.400000  English             152
# 5                               pathaan  0.000000    Hindi             146
# 6                                 raone  0.300000    Hindi             156
# 11                ballabhpurerroopkotha  0.476190  Bengali             136
# ..                                  ...       ...      ...             ...
# 494                           hollowman  0.166667  English             112
# 495                      theinterpreter  0.461538  English             128
# 496           percyjacksonseaofmonsters  0.150000  English             106
# 497  laracrofttombraiderthecradleoflife  0.300000  English             117
# 498                        nowyouseeme2  0.250000  English             129
#
#      IMDb_Rating     Animated  \
# 0            8.7  Live Action
# 1            9.0  Live Action
# 5            5.9  Live Action
# 6            4.7  Live Action
# 11           8.1  Live Action
# ..           ...          ...
# 494          5.7  Live Action
# 495          6.4  Live Action
# 496          5.8  Live Action
# 497          5.5  Live Action
# 498          6.5  Live Action
#
#                                                  Genre  Fantasy  Drama  Music  \
# 0                             Adventure, drama, sci-fi        1      1      1
# 1                                   Action,crime,drama        0      1      1
# 5                           Action, Thriller,Adventure        0      1      1
# 6                            Action, Adventure, Sci-fi        0      0      1
# 11                Supernatural, comedy, drama, romance        0      1      1
# ..                                                 ...      ...    ...    ...
# 494                   Action, Horror, Sci-Fi, Thriller        0      0      0
# 495                           Crime, Mystery, Thriller        0      1      0
# 496               Adventure, Family, Fantasy, Thriller        1      0      0
# 497               Action, Adventure, Fantasy, Thriller        0      1      0
# 498  Action, Adventure, Comedy, Crime, Mystery, Thr...        0      1      1
#
#      ...                 Lead_Actor              Lead_Actress  \
# 0    ...  Matthew David McConaughey  Anne Jacqueline Hathaway
# 1    ...             Christian Bale             Anne Hathaway
# 5    ...             Shah Rukh Khan          Deepika Padukone
# 6    ...             Shah Rukh Khan            Kareena Kapore
# 11   ...        Satyam Bhattacharya   Surangana Bandyopadhyay
# ..   ...                        ...                       ...
# 494  ...                Kevin Bacon            Elisabeth Shue
# 495  ...              Nicole Kidman                 Sean Penn
# 496  ...               Logan Lerman        Alexandra Daddario
# 497  ...             Angelina Jolie             Gerard Butler
# 498  ...            Jesse Eisenberg              Mark Ruffalo
#
#                  Director  Budget  BO Collection (Total)  Trailer Views  \
# 0       Christopher Nolan   165.0                 773.80       36314005
# 1       Christopher Nolan    18.5                 100.60      180000000
# 5         Siddharth Anand   225.0                1050.30       95215450
# 6           Anubhav Sinha   150.0                 207.00        2284960
# 11   Anirban Bhattacharya     3.0                   5.01        5416555
# ..                    ...     ...                    ...            ...
# 494        Paul Verhoeven    95.0                 190.20      190213455
# 495        Sydney Pollack    95.0                 162.90      190213455
# 496      Thor Freudenthal    90.0                 199.80      202359711
# 497           Jan de Bont    95.0                 156.50       65653758
# 498            Jon M. Chu    90.0                 334.90      334901337
#
#      Trailer Likes (K)  Music_Rating  No. of Screens      Verdict
# 0                202.0           8.5         20000.0  Blockbuster
# 1                185.0           9.4          4300.0          Hit
# 5               2400.0           8.0          6000.0  Blockbuster
# 6                 11.0           6.0          5000.0         Flop
# 11                16.0           7.7          2000.0          Hit
# ..                 ...           ...             ...          ...
# 494             3244.0           5.7          3000.0          Hit
# 495             3244.0           6.5          4000.0      Average
# 496             3778.0           5.8          1000.0      Average
# 497             3515.0           5.5          3000.0      Average
# 498             3815.0           6.6          3500.0          Hit
#
# [357 rows x 31 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le_verdict = LabelEncoder()

# %%
verdict_labels = ["Hit", "Superhit", "Flop", "Blockbuster", "Average", "Disaster"]

# %%
df['Animated'] = le.fit_transform(df['Animated'])
df['Lead_Actor'] = le.fit_transform(df['Lead_Actor'])
df['Lead_Actress'] = le.fit_transform(df['Lead_Actress'])
df['Language'] = le.fit_transform(df['Language'])
df['Director'] = le.fit_transform(df['Director'])
df['Verdict'] = le_verdict.fit_transform(df['Verdict'])
df
# Out:
#                              Movie Name       CSS  Language  Runtime (min.)  \
# 0                          interstellar  0.300000         1             169
# 1                         thedarkknight  0.400000         1             152
# 5                               pathaan  0.000000         2             146
# 6                                 raone  0.300000         2             156
# 11                ballabhpurerroopkotha  0.476190         0             136
# ..                                  ...       ...       ...             ...
# 494                           hollowman  0.166667         1             112
# 495                      theinterpreter  0.461538         1             128
# 496           percyjacksonseaofmonsters  0.150000         1             106
# 497  laracrofttombraiderthecradleoflife  0.300000         1             117
# 498                        nowyouseeme2  0.250000         1             129
#
#      IMDb_Rating  Animated                                              Genre  \
# 0            8.7         1                           Adventure, drama, sci-fi
# 1            9.0         1                                 Action,crime,drama
# 5            5.9         1                         Action, Thriller,Adventure
# 6            4.7         1                          Action, Adventure, Sci-fi
# 11           8.1         1               Supernatural, comedy, drama, romance
# ..           ...       ...                                                ...
# 494          5.7         1                   Action, Horror, Sci-Fi, Thriller
# 495          6.4         1                           Crime, Mystery, Thriller
# 496          5.8         1               Adventure, Family, Fantasy, Thriller
# 497          5.5         1               Action, Adventure, Fantasy, Thriller
# 498          6.5         1  Action, Adventure, Comedy, Crime, Mystery, Thr...
#
#      Fantasy  Drama  Music  ...  Lead_Actor  Lead_Actress  Director  Budget  \
# 0          1      1      1  ...         129            16        39   165.0
# 1          0      1      1  ...          45            15        39    18.5
# 5          0      1      1  ...         170            55       196   225.0
# 6          0      0      1  ...         170           136        16   150.0
# 11         0      1      1  ...         167           249        14     3.0
# ..       ...    ...    ...  ...         ...           ...       ...     ...
# 494        0      0      0  ...         112            61       149    95.0
# 495        0      1      0  ...         141           239       209    95.0
# 496        1      0      0  ...         120             4       212    90.0
# 497        0      1      0  ...          12            85        85    95.0
# 498        0      1      1  ...          94           168        96    90.0
#
#      BO Collection (Total)  Trailer Views  Trailer Likes (K)  Music_Rating  \
# 0                   773.80       36314005              202.0           8.5
# 1                   100.60      180000000              185.0           9.4
# 5                  1050.30       95215450             2400.0           8.0
# 6                   207.00        2284960               11.0           6.0
# 11                    5.01        5416555               16.0           7.7
# ..                     ...            ...                ...           ...
# 494                 190.20      190213455             3244.0           5.7
# 495                 162.90      190213455             3244.0           6.5
# 496                 199.80      202359711             3778.0           5.8
# 497                 156.50       65653758             3515.0           5.5
# 498                 334.90      334901337             3815.0           6.6
#
#      No. of Screens  Verdict
# 0           20000.0        1
# 1            4300.0        4
# 5            6000.0        1
# 6            5000.0        3
# 11           2000.0        4
# ..              ...      ...
# 494          3000.0        4
# 495          4000.0        0
# 496          1000.0        0
# 497          3000.0        0
# 498          3500.0        4
#
# [357 rows x 31 columns]

# %%
max_encoded_value = max(le_verdict.classes_)
print(le_verdict.classes_)
max_encoded_value
# Out:
# ['Average' 'Blockbuster' 'Disaster' 'Flop' 'Hit' 'Superhit']
# 'Superhit'

# %%
le_name_mapping = dict(zip(le_verdict.classes_, le_verdict.transform(le_verdict.classes_)))
le_name_mapping
# Out:
# {'Average': 0,
#  'Blockbuster': 1,
#  'Disaster': 2,
#  'Flop': 3,
#  'Hit': 4,
#  'Superhit': 5}

# %%
X = df.drop('Verdict', axis='columns')
X = df.drop('Movie Name', axis='columns')
X.drop('Genre', axis='columns', inplace=True)
# X['CSS'] = X['CSS'].fillna(X['CSS'].median())
# X['No. of Screens'] = X['No. of Screens'].fillna(X['No. of Screens'].median())
X
# Out:
#           CSS  Language  Runtime (min.)  IMDb_Rating  Animated  Fantasy  \
# 0    0.300000         1             169          8.7         1        1
# 1    0.400000         1             152          9.0         1        0
# 5    0.000000         2             146          5.9         1        0
# 6    0.300000         2             156          4.7         1        0
# 11   0.476190         0             136          8.1         1        0
# ..        ...       ...             ...          ...       ...      ...
# 494  0.166667         1             112          5.7         1        0
# 495  0.461538         1             128          6.4         1        0
# 496  0.150000         1             106          5.8         1        1
# 497  0.300000         1             117          5.5         1        0
# 498  0.250000         1             129          6.5         1        0
#
#      Drama  Music  Adventure  Thriller  ...  Lead_Actor  Lead_Actress  \
# 0        1      1          1         1  ...         129            16
# 1        1      1          1         1  ...          45            15
# 5        1      1          1         0  ...         170            55
# 6        0      1          1         0  ...         170           136
# 11       1      1          0         0  ...         167           249
# ..     ...    ...        ...       ...  ...         ...           ...
# 494      0      0          0         1  ...         112            61
# 495      1      0          0         0  ...         141           239
# 496      0      0          1         0  ...         120             4
# 497      1      0          1         1  ...          12            85
# 498      1      1          1         0  ...          94           168
#
#      Director  Budget  BO Collection (Total)  Trailer Views  \
# 0          39   165.0                 773.80       36314005
# 1          39    18.5                 100.60      180000000
# 5         196   225.0                1050.30       95215450
# 6          16   150.0                 207.00        2284960
# 11         14     3.0                   5.01        5416555
# ..        ...     ...                    ...            ...
# 494       149    95.0                 190.20      190213455
# 495       209    95.0                 162.90      190213455
# 496       212    90.0                 199.80      202359711
# 497        85    95.0                 156.50       65653758
# 498        96    90.0                 334.90      334901337
#
#      Trailer Likes (K)  Music_Rating  No. of Screens  Verdict
# 0                202.0           8.5         20000.0        1
# 1                185.0           9.4          4300.0        4
# 5               2400.0           8.0          6000.0        1
# 6                 11.0           6.0          5000.0        3
# 11                16.0           7.7          2000.0        4
# ..                 ...           ...             ...      ...
# 494             3244.0           5.7          3000.0        4
# 495             3244.0           6.5          4000.0        0
# 496             3778.0           5.8          1000.0        0
# 497             3515.0           5.5          3000.0        0
# 498             3815.0           6.6          3500.0        4
#
# [357 rows x 29 columns]

# %%
nan_columns = X.columns[X.isna().any()].tolist()
if nan_columns:
    print("Columns with NaN values:", nan_columns)
else:
    print("No NaN values found in any column.")
# Out:
# No NaN values found in any column.

# %%
y = df['Verdict']
y.dropna()
# Out:
# 0      1
# 1      4
# 5      1
# 6      3
# 11     4
#       ..
# 494    4
# 495    0
# 496    0
# 497    0
# 498    4
# Name: Verdict, Length: 357, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=None, oob_score=False,
#                        random_state=None, verbose=0, warm_start=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.9583333333333334

# %%
y_predicted = model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)

# %%
# %matplotlib inline
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
from sklearn.metrics import accuracy_score
ac = accuracy_score(y_test, y_predicted)
ac
# Out:
# 0.9583333333333334

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_predicted, average=None)
f1
# Out:
# array([1.        , 1.        , 0.96296296, 0.93333333, 0.8       ])
